# %%
# Load and Inspect the Script File
This notebook loads `Code.gs` and inspects its contents for syntax issues.

# %%
from pathlib import Path
file_path = Path(r"i:/My Drive/Wedding Plans/WeddingCard/Website/Code.gs")
code = file_path.read_text(encoding='utf-8')
print(f"Loaded {len(code.splitlines())} lines from {file_path}")
print('--- last 25 lines ---')
for line in code.splitlines()[-25:]:
    print(line)

# %%
# Reproduce the SyntaxError
Use a JavaScript parser to reproduce the reported "Unexpected end of input" error.
